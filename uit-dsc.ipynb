# %%
# !git clone https://github.com/thangquang09/UIT_DSC
# !pip install unsloth --quiet
# Out:
# Cloning into 'UIT_DSC'...
# remote: Enumerating objects: 43, done.
# remote: Counting objects: 100% (43/43), done.
# remote: Compressing objects: 100% (31/31), done.
# remote: Total 43 (delta 17), reused 35 (delta 9), pack-reused 0 (from 0)
# Receiving objects: 100% (43/43), 3.87 MiB | 16.49 MiB/s, done.
# Resolving deltas: 100% (17/17), done.
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.3/52.3 kB 2.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.2/42.2 kB 1.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 313.5/313.5 kB 8.1 MB/s eta 0:00:00:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 561.5/561.5 kB 18.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 544.8/544.8 kB 22.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.6/11.6 MB 98.4 MB/s eta 0:00:00:00:010:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 197.3/197.3 kB 11.0 MB/s eta 0:00:00
# ...

# %%
# %cd UIT_DSC
# Out:
# /kaggle/working/UIT_DSC

# %%
import os
os.environ['WANDB_API_KEY'] = "10bc3243ef5506402887d5e9da80a881b3cdca0b"

# %%
# !git pull
# !python main.py
# Out:
# remote: Enumerating objects: 7, done.
# remote: Counting objects: 100% (7/7), done.
# remote: Compressing objects: 100% (2/2), done.
# remote: Total 4 (delta 2), reused 4 (delta 2), pack-reused 0 (from 0)
# Unpacking objects: 100% (4/4), 381 bytes | 381.00 KiB/s, done.
# From https://github.com/thangquang09/UIT_DSC
#    9551e34..a26f698  main       -> origin/main
# Updating 9551e34..a26f698
# Fast-forward
#  src/config.py | 2 +-
#  1 file changed, 1 insertion(+), 1 deletion(-)
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# 2025-09-07 13:37:38.886934: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# ...
